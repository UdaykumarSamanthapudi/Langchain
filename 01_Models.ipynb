# %%
#Setting up the google api key in the environment
import os
os.environ["GOOGLE_API_KEY"]="AIzaSyDhGmnwNaiT3QS48Hg6yKmMn5jCRy_7lSk"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash",temperature=0.4,max_output_tokens=600)

# %%
res=llm.invoke("what is f1")
print((res))
# Out:
# content='F1 most commonly refers to **Formula 1**, which is the highest class of international racing for open' additional_kwargs={} response_metadata={'finish_reason': 'MAX_TOKENS', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019cccbb-e9ba-7241-9f97-a6c21281be9d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 596, 'total_tokens': 601, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 575}}

# %%
from langchain_core.messages import SystemMessage

res=llm.invoke([
    SystemMessage("U are a java developer, so when anyone asks what is ur profession say this"),"what is ur profession?"
])

print(res)
# Out:
# content='I am a Java developer.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019cccc1-1b7e-73a1-a9fd-333309cee2bf-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 22, 'output_tokens': 71, 'total_tokens': 93, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}

# %%
#Using batch method
res=llm.batch([
    "what is java?","what is python","what is a car"
])

for r in res:
    print(r.content)
# Out:
# Java is a **high-level, object-oriented, general-purpose programming language** that is widely used for developing
# Python is a **high-level, interpreted, general-purpose programming language** known for its **sim
# A **car** (short for automobile) is a wheeled motor vehicle used for transportation.
#
# Here's a

# %%
import os
os.environ["GOOGLE_API_KEY"]="AIzaSyBnwiHoj1F-2iSybumE_Vw3fqVuPB_oKoE"
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash",temperature=0.3)
for res in llm.stream("what is java"):
    print(res.content)
# Out:
# Java is a powerful, high-level, object-oriented programming language and computing platform that was first released by
#  Sun Microsystems (now owned by Oracle) in 1995.
#
# Here's a breakdown of what that means:
#
# 1.  **Programming Language:**
#     *   It's a set of instructions, syntax
# , and rules used to create software applications. Developers write code in Java, which is then compiled and run.
#
# 2.  **Object-Oriented (OOP):**
#     *   Java is built around the concept of "objects,"
#  which are instances of "classes." This paradigm helps organize complex software into reusable, modular components, making it easier to design, develop, and maintain applications. Key OOP principles include encapsulation, inheritance, and polymorphism.
#
# 3.  **High
# -Level:**
#     *   It's designed to be more human-readable and abstract away the complexities of computer hardware. You don't need to worry about memory management at a low level (like in C/C++), as
# ...
